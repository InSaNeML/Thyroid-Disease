# %%
# !ls
# Out:
# datalab

# %%
# !git clone https://github.com/InSaNeML/Thyroid-Disease.git
# !ls
# Out:
# Cloning into 'Thyroid-Disease'...
# remote: Counting objects: 140, done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 140 (delta 39), reused 128 (delta 31), pack-reused 0
# Receiving objects: 100% (140/140), 26.19 MiB | 61.38 MiB/s, done.
# Resolving deltas: 100% (39/39), done.
# datalab  Thyroid-Disease

# %% [markdown]
# file-id = "1PMJEk3hT-_ziNhSPkU9BllLYASLzN7TL"
# <br>
# destination = "train.zip"

# %%
import os
os.chdir("Thyroid-Disease")
# !ls
# Out:
# accuracy plot.png  download.py	   README.md		       transfer.py
# clean.py	   img_data	   src
# csv_data	   loss plot.png   thyroid classification.zip
# data		   make_folder.py  train.zip

# %%
# !python clean.py

# %%
# !python download.py 1PMJEk3hT-_ziNhSPkU9BllLYASLzN7TL train.zip

# %%
# !ls
# Out:
# accuracy plot.png  csv_data	loss plot.png	README.md  train.zip
# clean.py	   download.py	make_folder.py	src	   transfer.py

# %%
# !apt-get install unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-21ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.

# %%
# !unzip train.zip && mv train_ data
# Out:
# Archive:  train.zip
#    creating: train_/
#  extracting: train_/scan_0000.png
#  extracting: train_/scan_0001.png
#   inflating: train_/scan_00010.png
#  extracting: train_/scan_0001000.png
#  extracting: train_/scan_00010000.png
#  extracting: train_/scan_00010001.png
#  extracting: train_/scan_00010003.png
#  extracting: train_/scan_00010004.png
#  extracting: train_/scan_00010006.png
#  extracting: train_/scan_00010007.png
#  extracting: train_/scan_0001001.png
#  extracting: train_/scan_00010010.png
#  extracting: train_/scan_00010011.png
#  extracting: train_/scan_00010012.png
#  extracting: train_/scan_00010014.png
#  extracting: train_/scan_00010016.png
#  extracting: train_/scan_00010019.png
#  extracting: train_/scan_0001002.png
#  extracting: train_/scan_00010021.png
#  extracting: train_/scan_00010022.png
#  extracting: train_/scan_00010025.png
#  extracting: train_/scan_00010026.png
#  extracting: train_/scan_0001003.png
#  extracting: train_/scan_00010032.png
# ...

# %%
# !ls
# Out:
# accuracy plot.png  data		  make_folder.py  train.zip
# clean.py	   download.py	  README.md	  transfer.py
# csv_data	   loss plot.png  src

# %%
# !python make_folder.py
# Out:
# /content/Thyroid-Disease/img_data

# %%
# !python transfer.py
# Out:
# 0  files have been copied to train folder.
# 300  files have been copied to train folder.
# 600  files have been copied to train folder.
# 900  files have been copied to train folder.
# 1200  files have been copied to train folder.
# 1500  files have been copied to train folder.
# 1800  files have been copied to train folder.
# 2100  files have been copied to train folder.
# 2400  files have been copied to train folder.
# 2700  files have been copied to train folder.
# 3000  files have been copied to train folder.
# 3300  files have been copied to train folder.
# 3600  files have been copied to train folder.
# 3900  files have been copied to train folder.
# 4200  files have been copied to train folder.
# 4500  files have been copied to train folder.
# 4800  files have been copied to train folder.
# 5100  files have been copied to train folder.
# 5400  files have been copied to train folder.
# 5700  files have been copied to train folder.
# ...

# %%
# !python ./src/main.py
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# Importing data.
# Creating Conv2D model.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 126, 126, 32)      896
# _________________________________________________________________
# ...

# %%
import os
import shutil
os.chdir("../")
shutil.rmtree("Thyroid-Disease")
# !ls
# Out:
# datalab
